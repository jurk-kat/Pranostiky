# %% [markdown]
# Imports

# %%
import pandas as pd

# %%
katerina = pd.read_csv("data/katerina.csv")
vanoce = pd.read_csv("data/vanoce.csv")
katerina
# Out:
#       Unnamed: 0  latitude  longtitude  elevation        date  weather_code  \
# 0              0   50.0683     12.3913      483.0  1940-11-25           3.0
# 1              1   50.0683     12.3913      483.0  1941-11-25          51.0
# 2              2   50.0683     12.3913      483.0  1942-11-25           2.0
# 3              3   50.0683     12.3913      483.0  1943-11-25          55.0
# 4              4   50.0683     12.3913      483.0  1944-11-25          55.0
# ...          ...       ...         ...        ...         ...           ...
# 3355        3355   49.3650     17.8284      664.1  2019-11-25           3.0
# 3356        3356   49.3650     17.8284      664.1  2020-11-25           3.0
# 3357        3357   49.3650     17.8284      664.1  2021-11-25           3.0
# 3358        3358   49.3650     17.8284      664.1  2022-11-25           3.0
# 3359        3359   49.3650     17.8284      664.1  2023-11-25          73.0
#
# ...

# %%
# this part is under reconstruction. does not run so yet

# katerina.set_index('index', inplace=True)
# vanoce.set_index('index', inplace=True)

# katerina['year'] = pd.to_datetime(katerina['Date']).dt.year
# vanoce['year'] = pd.to_datetime(vanoce['Date']).dt.year

# merged_df = pd.merge(katerina, vanoce, on='index', suffixes=('_katerina', '_vanoce'))

# merged_df['yes'] = merged_df['Temperature_2m_mean_katerina'] > merged_df['Temperature_2m_mean_vanoce']

# result_df = merged_df[['Longtitude_katerina', 'Latitude_katerina', 'Elevation_katerina', 'year', 'yes']]

# result_df.to_csv('data/merged_result.csv', index=False)
